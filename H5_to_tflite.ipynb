# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetV2B0
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# Load model EfficientNetV2 untuk anti-spoofing
model = tf.keras.models.load_model("face_anti_spoofing_efficientnetv2_final.h5")

# Konversi ke TFLite (float32)
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Simpan model
with open("model_anti_spoofing_final_test.tflite", "wb") as f:
    f.write(tflite_model)

print("✅ Model berhasil dikonversi ke antispoof_float32.tflite")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\USER\AppData\Local\Temp\tmpxvfyxofl\assets
# INFO:tensorflow:Assets written to: C:\Users\USER\AppData\Local\Temp\tmpxvfyxofl\assets
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# ✅ Model berhasil dikonversi ke antispoof_float32.tflite
